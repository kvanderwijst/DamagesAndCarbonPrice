# %%
import numpy as np
import pandas as pd

from tqdm import tqdm

from visualisation.utils import *
from visualisation.sobol import *
from visualisation.plotsobol_cprice import *
from visualisation.emissionpathways import *

# %%
from carbontaxdamages.defaultparams import Params
from carbontaxdamages.run import full_run_structured, export_output
from carbontaxdamages.economics import *

# %%
dataset = 'Default'  # One of ['Default', 'No inertia', 'Drupp']

# %% [markdown]
# ## Import data

# %%
param_columns = ['SSP', 'damage', 'TCRE', 'cost_level', 'r']
r_values = {'0.1%': 0.001, '1.5%': 0.015, '3%': 0.03}
default_r = '1.5%'
default_elasmu = 'all'

# By default, make sure PRTP has uniform distribution
if 'r' in cost_and_TCRE_probs:
    del(cost_and_TCRE_probs['r'])

if dataset == 'Default':
    outputfolder = 'default'
    df, df_indexed = parse_input('experiment_allcba.csv', withInertia=True)
    df_CE, df_CE_indexed = parse_input('experiment_allcarbonbudget.csv', withInertia=True)
    
if dataset == 'No inertia':
    outputfolder = 'no_inertia'
    df, df_indexed = parse_input('experiment_allcba.csv', withInertia=False)
    df_CE, df_CE_indexed = parse_input('experiment_allcarbonbudget.csv', withInertia=False)
    
if dataset == 'Drupp':
    outputfolder = 'drupp'
    custom_map_names = dict(map_names)
    df, df_indexed = parse_input('experiment_allcbadrupp.csv', allElasmu=True, withInertia=False)
    df_CE, df_CE_indexed = parse_input('experiment_alldruppcarbonbudget.csv', allElasmu=True, withInertia=False)
    
    r_values = {'0.0_0.5': 0.0, '0.0_1.5': 0.0, '0.02_2.5': 0.02}
    default_r = '0.0_1.5'
    for _df in [df, df_CE]:
        _df['r'] = pd.Categorical(_df['r'].astype(str)+'_'+_df['elasmu'], list(r_values.keys()))
        _df['name'] = _df['name']+'_'+_df['elasmu']
        
    # Update the probabilities:
    cost_and_TCRE_probs['r'] = {
        'values': list(r_values.keys()),
        'p': cost_and_TCRE_probs['cost_level']['p']
    }

# %% [markdown]
# ## Individual factors

# %%
lowdamage = 'No damages'

fig1 = plot_individual(df_CE, 'cost_level', letter='a', legend_title='Cost level', lowdamage=lowdamage, r=default_r, elasmu=default_elasmu)
fig1.show()

fig2 = plot_individual(df_CE, 'SSP', ['SSP1', 'SSP3', 'SSP5'], 3, letter='b', lowdamage=lowdamage, r=default_r, elasmu=default_elasmu)
fig2.show()

fig3 = plot_individual(df_CE, 'TCRE', 'all', 6, letter='c', legend_title='TCRE', lowdamage=lowdamage, r=default_r, elasmu=default_elasmu)
fig3.show()

fig4 = plot_individual(df_CE, param_columns[-1], 'all', 11, letter='d', legend_title='PRTP', lowdamage=lowdamage, elasmu=default_elasmu)
fig4.show()
# Out:
# <div>
#
#
#             <div id="73468583-2f3e-46af-9997-9f54688092b2" class="plotly-graph-div" style="height:250px; width:750px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("73468583-2f3e-46af-9997-9f54688092b2")) {
#                     Plotly.newPlot(
#                         '73468583-2f3e-46af-9997-9f54688092b2',
#                         [{"legendgroup": "damage", "line": {"color": "rgba(0,0,0,0)"}, "mode": "lines", "name": "<i>Damage:</i>", "type": "scatter", "x": [null], "y": [null]}, {"hovertemplate": "cost_level=5th perc.<br>damage=Howard Total<br>name=SSP2 damageHowardTotal 0.00062 p05 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "#00AEEF", "dash": "solid"}, "mode": "lines", "name": "5th perc.", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [37.9773540775606, 137.03118506527485, 178.11843231738618, 193.39449198183067, 207.88720761005158, 222.68805928786188, 235.70663081818782, 249.57264676360225, 261.064090877276, 274.7206202327412, 285.8863859307435, 297.63708551639627, 306.6258846409372, 316.45336886205763, 323.5950071524619, 330.55264750082745, 335.3867932763588], "yaxis": "y"}, {"legendgroup": "damage", "line": {"color": "#000", "dash": "solid"}, "mode": "lines", "name": "Howard Total", "showlegend": true, "type": "scatter", "x": [null], "xaxis": "x", "y": [null], "yaxis": "y"}, {"hovertemplate": "cost_level=5th perc.<br>damage=No damages<br>name=SSP2 nodamage 0.00062 p05 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "
"orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [97.12944572359112, 186.22010782362239, 212.5490545597476, 239.80114206654181, 267.3994347303428, 299.0531998249294, 329.5641788280658, 364.92738722450724, 401.5471317270836, 445.5331579707257, 490.456213324386, 540.3984771751302, 594.1496137889053, 655.7265848753498, 722.4514380921088, 801.7525220276758, 885.6799784664078], "yaxis": "y"}, {"legendgroup": "damage", "line": {"color": "#000", "dash": "solid"}, "mode": "lines", "name": "Howard Total", "showlegend": true, "type": "scatter", "x": [null], "xaxis": "x", "y": [null], "yaxis": "y"}, {"hovertemplate": "TCRE=0.62<br>damage=Howard Total<br>name=SSP2 damageHowardTotal 0.00062 p50 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "#42B649", "dash": "solid"}, "mode": "lines", "name": "0.62", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [97.12944572359112, 225.9249335549371, 253.00826133886554, 281.33059509395287, 310.3933961823788, 339.01690344216604, 367.20522927811913, 400.1913558761918, 428.95369882983323, 464.5206799645443, 496.44904436277284, 533.3595057345171, 570.7817639615126, 611.5551664728428, 650.7016708833557, 686.7559553819752, 742.543807087598], "yaxis": "y"}, {"hovertemplate": "TCRE=0.62<br>damage=No damages<br>name=SSP2 nodamage 0.00062 p50 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "#42B649", "dash": "dot"}, "mode": "lines", "name": "0.62", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [77.36963910387135, 128.3969923499883, 151.45826265576412, 178.12720894520083, 209.2173443615185, 242.14832994496066, 279.5500360444627, 324.5700050625389, 373.50741571928563, 432.6978672182592, 496.4402163840015, 575.7093679633367, 653.5779932219829, 749.3037428015822, 840.1560580140605, 956.2833340840384, 1067.8746847116183], "yaxis": "y"}, {"legendgroup": "damage", "line": {"color": "#000", "dash": "dot"}, "mode": "lines", "name": "No damages", "showlegend": true, "type": "scatter", "x": [null], "xaxis": "x", "y": [null], "yaxis": "y"}, {"hovertemplate": "TCRE=0.82<br>damage=Howard Total<br>name=SSP2 damageHowardTotal 0.00082 p50 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "#EE2A23", "dash": "solid"}, "mode": "lines", "name": "0.82", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [97.12944572359112, 281.65938264675077, 316.78607784586603, 348.05041787828645, 379.66930626921067, 412.8963724564288, 441.4092555635151, 473.30103829970193, 502.23679282743865, 535.1093253975058, 563.887951263893, 595.9581812163456, 624.2399443949166, 652.6208687807003, 680.0965479467814, 707.9777869488101, 731.2335405009886], "yaxis": "y"}, {"legendgroup": "all", "line": {"color": "rgba(0,0,0,0)"}, "mode": "lines", "name": "<i>TCRE:</i>", "type": "scatter", "x": [null], "y": [null]}, {"hovertemplate": "TCRE=0.42<br>damage=Howard To ...
#                         {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "Price", "x": 0.215, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Emissions", "x": 0.785, "xanch
# <div>
#
#
#             <div id="745fbdb2-3bf8-439a-89ac-28ce330f20d1" class="plotly-graph-div" style="height:250px; width:750px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("745fbdb2-3bf8-439a-89ac-28ce330f20d1")) {
#                     Plotly.newPlot(
#                         '745fbdb2-3bf8-439a-89ac-28ce330f20d1',
#                         [{"legendgroup": "damage", "line": {"color": "rgba(0,0,0,0)"}, "mode": "lines", "name": "<i>Damage:</i>", "type": "scatter", "x": [null], "y": [null]}, {"hovertemplate": "r=0.1%<br>damage=Howard Total<br>name=SSP2 damageHowardTotal 0.00062 p50 0.001<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "#511607", "dash": "solid"}, "mode": "lines", "name": "0.1%", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [97.12944572359112, 370.03946188052976, 489.5516678142971, 513.663380582983, 537.0062873006765, 562.8807524712855, 582.4952895208337, 607.1144673003522, 625.4716156447178, 649.1867447600711, 670.2805681426843, 691.4614106398741, 708.4818845832627, 727.3202087230336, 742.0851168194962, 759.2059089244462, 769.1512035671419], "yaxis": "y"}, {"legendgroup": "damage", "line": {"color": "#000", "dash": "solid"}, "mode": "lines", "name": "Howard Total", "showlegend": true, "type": "scatter", "x": [null], "xaxis": "x", "y": [null], "yaxis": "y"}, {"hovertemplate": "r=0.1%<br>damage=No damages<br>name=SSP2 nodamage 0.00062 p50 0.001<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "#511607", "dash": "dot"}, "mode": "lines", "name": "0.1%", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [97.12944572359112, 237.54848832447084, 259.80154896534657, 282.43970742919015, 307.57302764777563, 334.8931662145717, 359.82899156483137, 389.16619391445465, 419.4591853727543, 453.21349766892286, 488.3387513082021, 530.0782839924432, 570.364214319723, 616.9627056828211, 661.9107721813695, 714.6813279483465, 758.2396532239425], "yaxis": "y"}, {"legendgroup": "damage", "line": {"color": "#000", "dash": "dot"}, "mode": "lines", "name": "No damages", "showlegend": true, "type": "scatter", "x": [null], "xaxis": "x", "y": [null], "yaxis": "y"}, {"hovertemplate": "r=1.5%<br>damage=Howard Total<br>name=SSP2 damageHowardTotal 0.00062 p50 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "#BA8912", "dash": "solid"}, "mode": "lines", "name": "1.5%", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [97.12944572359112, 225.9249335549371, 253.00826133886554, 281.33059509395287, 310.3933961823788, 339.01690344216604, 367.20522927811913, 400.1913558761918, 428.95369882983323, 464.5206799645443, 496.44904436277284, 533.3595057345171, 570.7817639615126, 611.5551664728428, 650.7016708833557, 686.7559553819752, 742.543807087598], "yaxis": "y"}, {"hovertemplate": "r=1.5%<br>damage=No damages<br>name=SSP2 nodamage 0.00062 p50 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "#BA8912", "dash": "dot"}, "mode": "lines", "name": "1.5%", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [77.36963910387135, 128.3969923499883, 151.45826265576412, 178.12720894520083, 209.2173443615185, 242.14832994496066, 279.5500360444627, 324.5700050625389, 373.50741571928563, 432.6978672182592, 496.4402163840015, 575.7093679633367, 653.5779932219829, 749.3037428015822, 840.1560580140605, 956.2833340840384, 1067.8746847116183], "yaxis": "y"}, {"hovertemplate": "r=3%<br>damage=Howard Total<br>name=SSP2 damageHowardTotal 0.00062 p50 0.03<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "#78CBBF", "dash": "solid"}, "mode": "lines", ...

# %%
fig1.write_image(f'../Paper/img/{outputfolder}/CE_individual_paths_a.png', scale=2)
fig2.write_image(f'../Paper/img/{outputfolder}/CE_individual_paths_b.png', scale=2)
fig3.write_image(f'../Paper/img/{outputfolder}/CE_individual_paths_c.png', scale=2)
fig4.write_image(f'../Paper/img/{outputfolder}/CE_individual_paths_d.png', scale=2)

# %% [markdown]
# ### Min emission level

# %%
fig1.update_traces(showlegend=False, line_color='rgba(0,0,0,0.15)')#.data
# Out:
# <div>
#
#
#             <div id="a2b17967-f81e-44f7-bd99-5a919938fb6b" class="plotly-graph-div" style="height:250px; width:750px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a2b17967-f81e-44f7-bd99-5a919938fb6b")) {
#                     Plotly.newPlot(
#                         'a2b17967-f81e-44f7-bd99-5a919938fb6b',
#                         [{"legendgroup": "damage", "line": {"color": "rgba(0,0,0,0.15)"}, "mode": "lines", "name": "<i>Damage:</i>", "showlegend": false, "type": "scatter", "x": [null], "y": [null]}, {"hovertemplate": "cost_level=5th perc.<br>damage=Howard Total<br>name=SSP2 damageHowardTotal 0.00062 p05 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "rgba(0,0,0,0.15)", "dash": "solid"}, "mode": "lines", "name": "5th perc.", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [37.9773540775606, 137.03118506527485, 178.11843231738618, 193.39449198183067, 207.88720761005158, 222.68805928786188, 235.70663081818782, 249.57264676360225, 261.064090877276, 274.7206202327412, 285.8863859307435, 297.63708551639627, 306.6258846409372, 316.45336886205763, 323.5950071524619, 330.55264750082745, 335.3867932763588], "yaxis": "y"}, {"legendgroup": "damage", "line": {"color": "rgba(0,0,0,0.15)", "dash": "solid"}, "mode": "lines", "name": "Howard Total", "showlegend": false, "type": "scatter", "x": [null], "xaxis": "x", "y": [null], "yaxis": "y"}, {"hovertemplate": "cost_level=5th perc.<br>damage=No damages<br>name=SSP2 nodamage 0.00062 p05 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "rgba(0,0,0,0.15)", "dash": "dot"}, "mode": "lines", "name": "5th perc.", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [29.67902377914769, 48.607336372535755, 57.94309791005644, 67.89946571859838, 79.24268120019164, 92.31179963409454, 106.55373460640742, 123.73301223454796, 142.2702211032881, 165.06116148510444, 190.4705111514788, 220.97839187816533, 264.1872654930852, 308.4309526705564, 349.96080327220136, 375.40872181677133, 415.5755126278772], "yaxis": "y"}, {"legendgroup": "damage", "line": {"color": "rgba(0,0,0,0.15)", "dash": "dot"}, "mode": "lines", "name": "No damages", "showlegend": false, "type": "scatter", "x": [null], "xaxis": "x", "y": [null], "yaxis": "y"}, {"hovertemplate": "cost_level=Median<br>damage=Howard Total<br>name=SSP2 damageHowardTotal 0.00062 p50 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "rgba(0,0,0,0.15)", "dash": "solid"}, "mode": "lines", "name": "Median", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [97.12944572359112, 225.9249335549371, 253.00826133886554, 281.33059509395287, 310.3933961823788, 339.01690344216604, 367.20522927811913, 400.1913558761918, 428.95369882983323, 464.5206799645443, 496.44904436277284, 533.3595057345171, 570.7817639615126, 611.5551664728428, 650.7016708833557, 686.7559553819752, 742.543807087598], "yaxis": "y"}, {"hovertemplate": "cost_level=Median<br>damage=No damages<br>name=SSP2 nodamage 0.00062 p50 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "rgba(0,0,0,0.15)", "dash": "dot"}, "mode": "lines", "name": "Median", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [77.36963910387135, 128.3969923499883, 151.45826265576412, 178.12720894520083, 209.2173443615185, 242.14832994496066, 279.5500360444627, 324.5700050625389, 373.50741571928563, 432.6978672182592, 496.4402163840015, 575.7093679633367, 653.5779932219829, 749.3037428015822, 840.1560580140605, 956.2833340840384, 1067.8746847116183], "yaxis": "y"}, {"hovertemplate": "cost_level=95th perc.<br>damage=Howard Tot ...

# %%
df_CE_minEmissions, df_CE_minEmissions_indexed = parse_input(
    'experiment_extra.csv', allElasmu=True, withInertia=True
)
lowdamage='No damages'

fig1_minEmissions = fig1.update_traces(showlegend=False, line_color='rgba(0,0,0,0.1)')
for trace in plot_individual(df_CE_minEmissions, 'cost_level', letter='a', legend_title='Cost level', lowdamage=lowdamage, r=default_r, elasmu=default_elasmu).data:
    fig1_minEmissions.add_trace(trace)
fig1_minEmissions.show()

fig2_minEmissions = fig2.update_traces(showlegend=False, line_color='rgba(0,0,0,0.1)')
for trace in plot_individual(df_CE_minEmissions, 'SSP', ['SSP1', 'SSP3', 'SSP5'], 3, letter='b', lowdamage=lowdamage, r=default_r, elasmu=default_elasmu).data:
    fig2_minEmissions.add_trace(trace)
fig2_minEmissions.show()

fig3_minEmissions = fig3.update_traces(showlegend=False, line_color='rgba(0,0,0,0.1)')
for trace in plot_individual(df_CE_minEmissions, 'TCRE', 'all', 6, letter='c', legend_title='TCRE', lowdamage=lowdamage, r=default_r, elasmu=default_elasmu).data:
    fig3_minEmissions.add_trace(trace)
fig3_minEmissions.show()

fig4_minEmissions = fig4.update_traces(showlegend=False, line_color='rgba(0,0,0,0.1)')
for trace in plot_individual(df_CE_minEmissions, param_columns[-1], 'all', 11, letter='d', legend_title='PRTP', lowdamage=lowdamage, elasmu=default_elasmu).data:
    fig4_minEmissions.add_trace(trace)
fig4_minEmissions.show()

fig1_minEmissions.write_image(f'../Paper/img/{outputfolder}/minEmissions_CE_individual_paths_a.png', scale=2)
fig2_minEmissions.write_image(f'../Paper/img/{outputfolder}/minEmissions_CE_individual_paths_b.png', scale=2)
fig3_minEmissions.write_image(f'../Paper/img/{outputfolder}/minEmissions_CE_individual_paths_c.png', scale=2)
fig4_minEmissions.write_image(f'../Paper/img/{outputfolder}/minEmissions_CE_individual_paths_d.png', scale=2)
# Out:
# <div>
#
#
#             <div id="4f599386-b06d-4818-b45d-54a8aa7532d8" class="plotly-graph-div" style="height:250px; width:750px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4f599386-b06d-4818-b45d-54a8aa7532d8")) {
#                     Plotly.newPlot(
#                         '4f599386-b06d-4818-b45d-54a8aa7532d8',
#                         [{"legendgroup": "damage", "line": {"color": "rgba(0,0,0,0.1)"}, "mode": "lines", "name": "<i>Damage:</i>", "showlegend": false, "type": "scatter", "x": [null], "y": [null]}, {"hovertemplate": "cost_level=5th perc.<br>damage=Howard Total<br>name=SSP2 damageHowardTotal 0.00062 p05 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "rgba(0,0,0,0.1)", "dash": "solid"}, "mode": "lines", "name": "5th perc.", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y":
"orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [97.12944572359112, 186.22010782362239, 212.5490545597476, 239.80114206654181, 267.3994347303428, 299.0531998249294, 329.5641788280658, 364.92738722450724, 401.5471317270836, 445.5331579707257, 490.456213324386, 540.3984771751302, 594.1496137889053, 655.7265848753498, 722.4514380921088, 801.7525220276758, 885.6799784664078], "yaxis": "y"}, {"legendgroup": "damage", "line": {"color": "rgba(0,0,0,0.1)", "dash": "solid"}, "mode": "lines", "name": "Howard Total", "showlegend": false, "type": "scatter", "x": [null], "xaxis": "x", "y": [null], "yaxis": "y"}, {"hovertemplate": "TCRE=0.62<br>damage=Howard Total<br>name=SSP2 damageHowardTotal 0.00062 p50 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "rgba(0,0,0,0.1)", "dash": "solid"}, "mode": "lines", "name": "0.62", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [97.12944572359112, 225.9249335549371, 253.00826133886554, 281.33059509395287, 310.3933961823788, 339.01690344216604, 367.20522927811913, 400.1913558761918, 428.95369882983323, 464.5206799645443, 496.44904436277284, 533.3595057345171, 570.7817639615126, 611.5551664728428, 650.7016708833557, 686.7559553819752, 742.543807087598], "yaxis": "y"}, {"hovertemplate": "TCRE=0.62<br>damage=No damages<br>name=SSP2 nodamage 0.00062 p50 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "rgba(0,0,0,0.1)", "dash": "dot"}, "mode": "lines", "name": "0.62", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [77.36963910387135, 128.3969923499883, 151.45826265576412, 178.12720894520083, 209.2173443615185, 242.14832994496066, 279.5500360444627, 324.5700050625389, 373.50741571928563, 432.6978672182592, 496.4402163840015, 575.7093679633367, 653.5779932219829, 749.3037428015822, 840.1560580140605, 956.2833340840384, 1067.8746847116183], "yaxis": "y"}, {"legendgroup": "damage", "line": {"color": "rgba(0,0,0,0.1)", "dash": "dot"}, "mode": "lines", "name": "No damages", "showlegend": false, "type": "scatter", "x": [null], "xaxis": "x", "y": [null], "yaxis": "y"}, {"hovertemplate": "TCRE=0.82<br>damage=Howard Total<br>name=SSP2 damageHowardTotal 0.00082 p50 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "rgba(0,0,0,0.1)", "dash": "solid"}, "mode": "lines", "name": "0.82", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [97.12944572359112, 281.65938264675077, 316.78607784586603, 348.05041787828645, 379.66930626921067, 412.8963724564288, 441.4092555635151, 473.30103829970193, 502.23679282743865, 535.1093253975058, 563.887951263893, 595.9581812163456, 624.2399443949166, 652.6208687807003, 680.0965479467814, 707.9777869488101, 731.2335405009886], "yaxis": "y"}, {"legendgroup": "all", "line": {"color": "rgba(0,0,0,0.1)"}, "mode": "lines", "name": "<i>TCRE:</i>", "showlegend": ...
# <div>
#
#
#             <div id="7bb60b26-e11d-4008-889b-1fc13c24420f" class="plotly-graph-div" style="height:250px; width:750px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7bb60b26-e11d-4008-889b-1fc13c24420f")) {
#                     Plotly.newPlot(
#                         '7bb60b26-e11d-4008-889b-1fc13c24420f',
#                         [{"legendgroup": "damage", "line": {"color": "rgba(0,0,0,0.1)"}, "mode": "lines", "name": "<i>Damage:</i>", "showlegend": false, "type": "scatter", "x": [null], "y": [null]}, {"hovertemplate": "r=0.1%<br>damage=Howard Total<br>name=SSP2 damageHowardTotal 0.00062 p50 0.001<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "rgba(0,0,0,0.1)", "dash": "solid"}, "mode": "lines", "name": "0.1%", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [97.12944572359112, 370.03946188052976, 489.5516678142971, 513.663380582983, 537.0062873006765, 562.8807524712855, 582.4952895208337, 607.1144673003522, 625.4716156447178, 649.1867447600711, 670.2805681426843, 691.4614106398741, 708.4818845832627, 727.3202087230336, 742.0851168194962, 759.2059089244462, 769.1512035671419], "yaxis": "y"}, {"legendgroup": "damage", "line": {"color": "rgba(0,0,0,0.1)", "dash": "solid"}, "mode": "lines", "name": "Howard Total", "showlegend": false, "type": "scatter", "x": [null], "xaxis": "x", "y": [null], "yaxis": "y"}, {"hovertemplate": "r=0.1%<br>damage=No damages<br>name=SSP2 nodamage 0.00062 p50 0.001<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "rgba(0,0,0,0.1)", "dash": "dot"}, "mode": "lines", "name": "0.1%", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [97.12944572359112, 237.54848832447084, 259.80154896534657, 282.43970742919015, 307.57302764777563, 334.8931662145717, 359.82899156483137, 389.16619391445465, 419.4591853727543, 453.21349766892286, 488.3387513082021, 530.0782839924432, 570.364214319723, 616.9627056828211, 661.9107721813695, 714.6813279483465, 758.2396532239425], "yaxis": "y"}, {"legendgroup": "damage", "line": {"color": "rgba(0,0,0,0.1)", "dash": "dot"}, "mode": "lines", "name": "No damages", "showlegend": false, "type": "scatter", "x": [null], "xaxis": "x", "y": [null], "yaxis": "y"}, {"hovertemplate": "r=1.5%<br>damage=Howard Total<br>name=SSP2 damageHowardTotal 0.00062 p50 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "rgba(0,0,0,0.1)", "dash": "solid"}, "mode": "lines", "name": "1.5%", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [97.12944572359112, 225.9249335549371, 253.00826133886554, 281.33059509395287, 310.3933961823788, 339.01690344216604, 367.20522927811913, 400.1913558761918, 428.95369882983323, 464.5206799645443, 496.44904436277284, 533.3595057345171, 570.7817639615126, 611.5551664728428, 650.7016708833557, 686.7559553819752, 742.543807087598], "yaxis": "y"}, {"hovertemplate": "r=1.5%<br>damage=No damages<br>name=SSP2 nodamage 0.00062 p50 0.015<br>year=%{x}<br>p=%{y}<extra></extra>", "legendgroup": "all", "line": {"color": "rgba(0,0,0,0.1)", "dash": "dot"}, "mode": "lines", "name": "1.5%", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0], "xaxis": "x", "y": [77.36963910387135, 128.3969923499883, 151.45826265576412, 178.12720894520083, 209.2173443615185, 242.14832994496066, 279.5500360444627, 324.5700050625389, 373.50741571928563, 432.6978672182592, 496.4402163840015, 575.7093679633367, 653.5779932219829, 749.3037428015822, 840.1560580140605, 956.2833340840384, 1067.8746847116183], "yaxis": "y"}, {"hovertemplate": "r=3%<br>damage=Howard Total<br>name=SSP2 damageHowardTotal 0.00062 p50 0.03<br>year=%{x}<br>p=%{y}<extra></extra>", "legen ...

# %% [markdown]
# ### Increased initial carbon price compared to no-damages

# %%
year = 2025

try:
    _tmp_df = df_CE_indexed
    values = [
        [
            _tmp_df.loc[('SSP2', 'No damages', '0.62', '5th perc.', '1.5%', '2.0', '1.001', year), 'p'],
            _tmp_df.loc[('SSP2', 'Howard Total', '0.62', '5th perc.', '1.5%', '2.0', '1.001', year), 'p'],
            _tmp_df.loc[('SSP2', 'DICE', '0.62', '5th perc.', '1.5%', '2.0', '1.001', year), 'p'],
            _tmp_df.loc[('SSP2', 'Burke (LR)', '0.62', '5th perc.', '1.5%', '2.0', '1.001', year), 'p']
        ],
        [
            _tmp_df.loc[('SSP2', 'No damages', '0.62', 'Median', '1.5%', '2.0', '1.001', year), 'p'],
            _tmp_df.loc[('SSP2', 'Howard Total', '0.62', 'Median', '1.5%', '2.0', '1.001', year), 'p'],
            _tmp_df.loc[('SSP2', 'DICE', '0.62', 'Median', '1.5%', '2.0', '1.001', year), 'p'],
            _tmp_df.loc[('SSP2', 'Burke (LR)', '0.62', 'Median', '1.5%', '2.0', '1.001', year), 'p']
        ],
        [
            _tmp_df.loc[('SSP2', 'No damages', '0.62', '95th perc.', '1.5%', '2.0', '1.001', year), 'p'],
            _tmp_df.loc[('SSP2', 'Howard Total', '0.62', '95th perc.', '1.5%', '2.0', '1.001', year), 'p'],
            _tmp_df.loc[('SSP2', 'DICE', '0.62', '95th perc.', '1.5%', '2.0', '1.001', year), 'p'],
            _tmp_df.loc[('SSP2', 'Burke (LR)', '0.62', '95th perc.', '1.5%', '2.0', '1.001', year), 'p']
        ]
    ]
    print("                         [costs: 5th, 50th, 95th percentiles]\n")
    print("HowardTotal vs nodamage:", [v[1]/v[0] for v in values])
    print("DICE vs nodamage:", [v[2]/v[0] for v in values])
    print("Burke (LR) vs nodamage:", [v[3]/v[0] for v in values])
    
except KeyError as e:
    print("Key does not exist:", e)
# Out:
#                          [costs: 5th, 50th, 95th percentiles]
#
# HowardTotal vs nodamage: [2.8191461473025825, 1.7595811975026976, 1.319228349530206]
# DICE vs nodamage: [1.4635523501068186, 1.1724837667344852, 1.0794810220533124]
# Burke (LR) vs nodamage: [3.1049252128754348, 2.7114132193248377, 1.9032880224402038]

# %% [markdown]
# And for the discount rate:

# %%
try:
    values = [
        [
            _tmp_df.loc[('SSP2', 'No damages', '0.62', 'Median', '0.1%', '2.0', '1.45', year), 'p'],
            _tmp_df.loc[('SSP2', 'No damages', '0.62', 'Median', '1.5%', '2.0', '1.45', year), 'p'],
            _tmp_df.loc[('SSP2', 'No damages', '0.62', 'Median', '3%', '2.0', '1.45', year), 'p']
        ],
        [
            _tmp_df.loc[('SSP2', 'Howard Total', '0.62', 'Median', '0.1%', '2.0', '1.45', year), 'p'],
            _tmp_df.loc[('SSP2', 'Howard Total', '0.62', 'Median', '1.5%', '2.0', '1.45', year), 'p'],
            _tmp_df.loc[('SSP2', 'Howard Total', '0.62', 'Median', '3%', '2.0', '1.45', year), 'p']
        ],
        [
            _tmp_df.loc[('SSP2', 'Burke (LR)', '0.62', 'Median', '0.1%', '2.0', '1.45', year), 'p'],
            _tmp_df.loc[('SSP2', 'Burke (LR)', '0.62', 'Median', '1.5%', '2.0', '1.45', year), 'p'],
            _tmp_df.loc[('SSP2', 'Burke (LR)', '0.62', 'Median', '3%', '2.0', '1.45', year), 'p']
        ]
    ]
    print("0.1% vs 1.5%:", [v[0]/v[1] for v in values])
    print("1.5% vs 3%:", [v[1]/v[2] for v in values])
    print("0.1% vs 3%:", [v[0]/v[2] for v in values])
    
except KeyError as e:
    print("Key does not exist:", e)
# Out:
# Key does not exist: ('SSP2', 'No damages', '0.62', 'Median', '0.1%', '2.0', '1.45', 2025)

# %% [markdown]
# ## Sobol analysis on 2030/2050/2070 price

# %%
years = np.arange(2030, 2101, 5)

split_param = 'cost_level'
subplot_titles = (
    'All mitigation cost levels', 
    'Mitig. cost level: 5th perc.', 'Mitig. cost level: median', 'Mitig. cost level: 95th perc.'
)

# %%
for relative in [True, False]:
    sobol_CE_per_year = calculate_sobol_cprices(df_CE, split_param, relative, param_columns, years, cost_and_TCRE_probs, num=10**6)
    
    for use_sqrt in [True, False]:
        if relative and use_sqrt:
            continue
            
        fig_sobol_cprice_CE = plotsobol_cprice(sobol_CE_per_year, use_sqrt, subplot_titles, relative, param_columns, years)
        
        if relative:
            suffix = '_relative'
        else:
            suffix = '_absolute_sqrt' if use_sqrt else '_absolute_variance'

        fig_sobol_cprice_CE.write_image(f'../Paper/img/{outputfolder}/CE_partial_uncertainty{suffix}.png', scale=2)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 15/15 [01:30<00:00,  6.04s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 15/15 [01:32<00:00,  6.19s/it]

# %%
sobol_CE_per_year_nodmg = calculate_sobol_cprices(
    df_CE, split_param, False, param_columns, years, 
    {'cost_level': cost_and_TCRE_probs['cost_level']}, num=10**6, valid_dmg_fcts=['No damages']
)
fig_sobol_cprice_CE_nodmg = plotsobol_cprice(
    sobol_CE_per_year_nodmg, False, subplot_titles, False, param_columns, years
)
fig_sobol_cprice_CE_nodmg.write_image(f'../Paper/img/{outputfolder}/CE_partial_uncertainty_absolute_variance_nodmg.png', scale=2)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 15/15 [01:23<00:00,  5.53s/it]

# %% [markdown]
# ## Mitigation costs vs damage costs

# %%
damage_functions_2 = {
    'No damages': damages['nodamage'],
    'DICE': damages['damageDICE'],
    'Burke (LR)': damages['damageBurkeWithLag']['SSP2'],
    'Howard Total': damages['damageHowardTotal']
}

# %%
T0 = 1.0 + 4 * 0.00062 * 38.8

def mitigation_vs_damages(
    SSP='SSP2', 
    r=default_r, 
    cost_level='Median', 
    TCRE='0.62', 
    damage='Howard Total', 
    elasmu=default_elasmu,
    max_y=0.149, title=''
):
    
    selection1 = df_CE[
        (df_CE['SSP'] == SSP) & (df_CE['r'] == r) & (df_CE['cost_level'] == cost_level)
        & ((df_CE['elasmu'] == elasmu) | (elasmu == 'all')) & (df_CE['beta'] == '2.0')
        & (df_CE['TCRE'] == TCRE) & (df_CE['damage'] == damage)
    ]

    selection1b = df_CE[
        (df_CE['SSP'] == SSP) & (df_CE['r'] == r) & (df_CE['cost_level'] == cost_level)
        & ((df_CE['elasmu'] == elasmu) | (elasmu == 'all')) & (df_CE['beta'] == '2.0')
        & (df_CE['TCRE'] == TCRE) & (df_CE['damage'] == 'No damages')
    ]

    selection2 = df[
        (df['SSP'] == SSP) & (df['r'] == r) & (df['cost_level'] == cost_level)
        & ((df['elasmu'] == elasmu) | (elasmu == 'all')) & (df['beta'] == '2.0')
        & (df['TCRE'] == TCRE) & (df['damage'] == damage)
    ]

    t_values_years = np.linspace(2020, 2150, 27)
    dt = t_values_years[1] - t_values_years[0]
    temp_values = np.cumsum(baseline_emissions(t_values_years, SSP) * dt) * float(TCRE) / 1000 + T0
    
    T_2100_baseline = np.interp(2100, t_values_years, temp_values)
    T_2100_with = selection1[selection1['year'] == 2100]['temp'].values[0]
    T_2100_without = selection2[selection2['year'] == 2100]['temp'].values[0]
    
    fig = make_subplots(1, 3, subplot_titles=(
        'Baseline<br>(T<sub>2100</sub>: {:.1f}°C)'.format(T_2100_baseline),
        'With target<br>(T<sub>2100</sub>: {:.1f}°C)'.format(T_2100_with),
        'Without target<br>(T<sub>2100</sub>: {:.1f}°C)'.format(T_2100_without)
    ), shared_yaxes=True)
    

    fig.append_trace(go.Scatter(x=t_values_years, y=[damage_functions_2[damage](T) for T in temp_values], stackgroup='baseline', fillcolor=colors_PBL[0], line_width=0, showlegend=False, legendgroup='damages'), 1, 1)

    fig.append_trace(go.Scatter(x=selection1['year'], y=selection1['abatementFraction'], stackgroup='withtarget', fillcolor=colors_PBL[2], line_width=0, name='Mitigation costs', legendgroup='mitigation'), 1, 2)
    fig.append_trace(go.Scatter(x=selection1['year'], y=selection1['damageFraction'], stackgroup='withtarget', fillcolor=colors_PBL[0], line_width=0, name='Damages', legendgroup='damages'), 1, 2)

    fig.append_trace(go.Scatter(x=selection1b['year'], y=selection1b['abatementFraction'], line_color='#000', line_dash='dot', name='Mitigation costs<br>(cost effective)', legendgroup='costeffective'), 1, 2)

    fig.append_trace(go.Scatter(x=selection2['year'], y=selection2['abatementFraction'], stackgroup='withouttarget', fillcolor=colors_PBL[2], line_width=0, showlegend=False, legendgroup='mitigation'), 1, 3)
    fig.append_trace(go.Scatter(x=selection2['year'], y=selection2['damageFraction'], stackgroup='withouttarget', fillcolor=colors_PBL[0], line_width=0, showlegend=False, legendgroup='damages'), 1, 3)

    fig.update_xaxes(range=[2021,2100])
    fig.update_xaxes(range=[2021,2100], col=3)
    fig.update_yaxes(range=[0, max_y], tickformat=',.0%')
    fig.update_layout(
        legend_y=0.5, margin={'t': 110, 'b': 0, 'l': 30},
        width=950, height=320, yaxis1={'title': 'Share of world GDP', 'title_standoff': 10},
        title={'text':title, 'x': 0}
    )
    
    return fig

fig1 = mitigation_vs_damages(cost_level='5th perc.', damage='Burke (LR)', title='<b>a. Low costs, damage: Burke (LR)</b>')
fig1.show()
fig2 = mitigation_vs_damages(cost_level='Median', damage='Howard Total', title='<b>b. Medium costs, damage: Howard Total</b>')
fig2.show()
fig3 = mitigation_vs_damages(cost_level='95th perc.', damage='DICE', title='<b>c. High costs, damage: DICE</b>')
fig3.show()
# Out:
# <div>
#
#
#             <div id="e1413ce3-522a-4b0c-a4dd-5b35e51363fe" class="plotly-graph-div" style="height:320px; width:950px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e1413ce3-522a-4b0c-a4dd-5b35e51363fe")) {
#                     Plotly.newPlot(
#                         'e1413ce3-522a-4b0c-a4dd-5b35e51363fe',
#                         [{"fillcolor": "#00AEEF", "legendgroup": "damages", "line": {"width": 0}, "showlegend": false, "stackgroup": "baseline", "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0, 2105.0, 2110.0, 2115.0, 2120.0, 2125.0, 2130.0, 2135.0, 2140.0, 2145.0, 2150.0], "xaxis": "x", "y": [0.004512999499880662, 0.011998413435993439, 0.023232441173385854, 0.03798080888095746, 0.05629130240275224, 0.07799338452972449, 0.10315372938886885, 0.1313250015851692, 0.1619061079338643, 0.1950128448404851, 0.23027425829874343, 0.26753201942686616, 0.3064379926985038, 0.34666659377244063, 0.38755675396558703, 0.4291115125763366, 0.4709728669584592, 0.512799707343267, 0.5544839632397884, 0.5953107914774475, 0.635171279178816, 0.673423331822894, 0.7099695189107967, 0.7443324595507845, 0.7764927801151212, 0.8061106214533366, 0.833256159204123], "yaxis": "y"}, {"fillcolor": "#B6036C", "legendgroup": "mitigation", "line": {"width": 0}, "name": "Mitigation costs", "stackgroup": "withtarget", "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0, 2105.0, 2110.0, 2115.0, 2120.0, 2125.0, 2130.0, 2135.0, 2140.0, 2145.0, 2150.0, 2155.0, 2160.0, 2165.0, 2170.0, 2175.0, 2180.0, 2185.0, 2190.0, 2195.0, 2200.0], "xaxis": "x2", "y": [0.019549554147304485, 0.022525623061027608, 0.02449471962522803, 0.025666696984931188, 0.025511910993337196, 0.02522948345486184, 0.024711398584427124, 0.02370603489419613, 0.022376888652063668, 0.02244712751189537, 0.02072967872193257, 0.01938161066812138, 0.018306021308510643, 0.01689438600761383, 0.015662875065433998, 0.014617196075589547, 0.01318386107153718, 0.012473700706025872, 0.011372882226448245, 0.009933265387934972, 0.009244910640943916, 0.008594092735293341, 0.008326794722281022, 0.008121417594022521, 0.007928710248029162, 0.007780715777112964, 0.007640798853919922, 0.007539961818551016, 0.0074448408378701035, 0.007354884241311692, 0.007269613796624325, 0.007188612454267241, 0.007111514519893773, 0.007037997703489825, 0.006967776633837256, 0.006900597527962275, 0.00683623377892512], "yaxis": "y2"}, {"fillcolor": "#00AEEF", "legendgroup": "damages", "line": {"width": 0},
005922519259639485, 0.005922519256466357, 0.005922519253574287, 0.005922519250927543, 0.005922519248496196, 0.005922519246254991, 0.005922519244182464, 0.005922519242260268, 0.005922519240472616], "yaxis": "y2"}, {"legendgroup": "costeffective", "line": {"color": "#000", "dash": "dot"}, "name": "Mitigation costs<br>(cost effective)", "type": "scatter", "x": [2020.0, 2025.0, 2030.0, 2035.0, 2040.0, 2045.0, 2050.0, 2055.0, 2060.0, 2065.0, 2070.0, 2075.0, 2080.0, 2085.0, 2090.0, 2095.0, 2100.0, 2105.0, 2110.0, 2115.0, 2120.0, 2125.0, 2130.0, 2135.0, 2140.0, 2145.0, 2150.0, 2155.0, 2160.0, 2165.0, 2170.0, 2175.0, 2180.0, 2185 ...
#                         {"annotations": [{"font": {"size

# %%
fig1.write_image(f'../Paper/img/{outputfolder}/mitigation_vs_damages_a.png', scale=2)
fig2.write_image(f'../Paper/img/{outputfolder}/mitigation_vs_damages_b.png', scale=2)
fig3.write_image(f'../Paper/img/{outputfolder}/mitigation_vs_damages_c.png', scale=2)

# %% [markdown]
# ## Mitigation costs vs avoided damages

# %%
damage_functions = {
    'No damages': damages['nodamage'],
    'DICE': damages['damageDICE'],
    'Burke (LR)': damages['damageBurkeWithLag'],
    'Howard Total': damages['damageHowardTotal']
}

# %%
def baseline_damages(SSP, damage, TCRE, t_values_years):
    T0 = Params().default_params['T0']
    dt = t_values_years[1] - t_values_years[0]
    temp_values = np.cumsum(baseline_emissions(t_values_years, SSP) * dt) * float(TCRE) / 1000 + T0
    dmg_fct = damage_functions[damage][SSP] if damage == 'Burke (LR)' else damage_functions[damage]
    return [dmg_fct(T) for T in temp_values]

def calcBaselineDamages(sub_df):
    SSP,damage,TCRE = sub_df.iloc[0][['SSP','damage','TCRE']]
    sub_df['baselineDamages'] = baseline_damages(SSP, damage, TCRE, sub_df['year'].values)
    return sub_df

def npv_series(selection, name):
    selection['{} NPV'.format(name)] = selection[name] * np.exp(-selection['r_num'] * (selection['year'] - 2020))
    #return discounted_values.groupby(param_columns).sum()
    
def calc_costs_vs_benefits(selection):
    selection['damage'] = pd.Categorical(selection['damage'], selection['damage'].unique())
    selection['baselineDamages'] = np.nan
    
    selection = selection.groupby(param_columns).apply(calcBaselineDamages)
    
    selection['abatement_costs'] = selection['abatementFraction'] * selection['Ygross']
    selection['remaining_damage_costs'] = selection['damageFraction'] * selection['Ygross']
    selection['avoided_damages'] = selection['baselineDamages'] * selection['Ygross'] - selection['remaining_damage_costs']
    
    selection['r_num'] = selection['r'].replace(r_values)
    
    npv_series(selection, 'abatement_costs')
    npv_series(selection, 'avoided_damages')
    npv_series(selection, 'Y')
    
    NPV_values = selection.groupby(param_columns)[['abatement_costs NPV', 'avoided_damages NPV', 'Y NPV']].sum().reset_index()
    NPV_values['abatement_costs NPV relative'] = NPV_values['abatement_costs NPV'] / NPV_values['Y NPV']
    NPV_values['avoided_damages NPV relative'] = NPV_values['avoided_damages NPV'] / NPV_values['Y NPV']
    
    NPV_values['damage'] = pd.Categorical(NPV_values['damage'], ['DICE', 'Howard Total', 'Burke (LR)'])
    NPV_values = NPV_values.sort_values(param_columns)
    
    return NPV_values

# %%
selection_CBA = df.loc[
    (df['damage'].isin(['DICE', 'Burke (LR)', 'Howard Total']))
    & (df['year'] <= 2100)
    & (df['TCRE'].isin(['0.42','0.62','0.82'])), :
].copy()

# %%
selection_CE = df_CE.loc[(df_CE['damage'].isin(['DICE', 'Burke (LR)', 'Howard Total'])) & (df_CE['year'] <= 2100),:].copy()

# %%
NPV_values_CBA = calc_costs_vs_benefits(selection_CBA)
NPV_values_CBA['type'] = 'CBA'
NPV_values_CE = calc_costs_vs_benefits(selection_CE)
NPV_values_CE['type'] = 'CE'

# %%
selection1 = NPV_values_CE.loc[NPV_values_CE['damage'].isin(['Howard Total', 'Burke (LR)'])]
print((
    selection1['avoided_damages NPV relative'] > 0.99 * selection1['abatement_costs NPV relative']
).mean())

selection2 = NPV_values_CE.loc[NPV_values_CE['damage'].isin(['DICE'])]
print((
    selection2['avoided_damages NPV relative'] > 0.99 * selection2['abatement_costs NPV relative']
).mean())
# Out:
# 0.937037037037037
# 0.4074074074074074

# %%
selection1 = NPV_values_CE.loc[NPV_values_CE['damage'].isin(['Howard Total', 'Burke (LR)'])]
print((
    selection1['avoided_damages NPV relative'] > 0.99 * selection1['abatement_costs NPV relative']
).mean())

selection2 = NPV_values_CE.loc[NPV_values_CE['damage'].isin(['DICE'])]
print((
    selection2['avoided_damages NPV relative'] > 0.99 * selection2['abatement_costs NPV relative']
).mean())
# Out:
# 0.9481481481481482
# 0.4

# %%
NPV_values = NPV_values_CE

symbols = ['circle-open', 'square', 'star']

fig = px.scatter(
    NPV_values, x='abatement_costs NPV relative', y='avoided_damages NPV relative',
    color='damage', range_x=[0,0.17], hover_data=['SSP'], symbol='cost_level', symbol_sequence=symbols, hover_name='TCRE'
)
fig.update_traces(showlegend=False)

for color, damage in zip(px.colors.qualitative.Plotly[:3][::-1], NPV_values['damage'].unique()[::-1]):
    fig.add_trace(go.Scatter(
        x=[None],y=[None],mode='markers',marker_color=color, name='Damage: {}'.format(damage), legendgroup='damage'
    ))

for symbol, cost_level in zip(symbols, NPV_values['cost_level'].unique()):
    fig.add_trace(go.Scatter(
        x=[None],y=[None],mode='markers',marker_color='#000', marker_symbol=symbol,
        name='Cost level: {}'.format(cost_level), legendgroup='cost_level'
    ))

x_values = np.linspace(0,0.3,100)
fig.add_trace(go.Scatter(x=x_values, y=x_values, name='x=y line', line_color='#BBB'))

fig.update_layout(
    legend={'tracegroupgap': 15, 'y': 0.5, 'font_size': 13, 'title': None},
    width=850, height=500, margin={'t': 20},
    xaxis={'title': '<b>Costs</b><br>(NPV Abatement costs / GDP)', 'tickformat': ',.0%', 'range': [-0.0025, 0.1092]},
    yaxis={'title': '<b>Benefits</b><br>(NPV Avoided damages / GDP)', 'tickformat': ',.0%', 'range': [-0.0212, 0.52]},
)

fig.show()
# Out:
# <div>
#
#
#             <div id="5970de03-168d-4825-8e2c-d9fb1ae3cbc0" class="plotly-graph-div" style="height:500px; width:850px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5970de03-168d-4825-8e2c-d9fb1ae3cbc0")) {
#                     Plotly.newPlot(
#                         '5970de03-168d-4825-8e2c-d9fb1ae3cbc0',
#                         [{"customdata": [["SSP1"], ["SSP1"], ["SSP1"], ["SSP1"], ["SSP1"], ["SSP1"], ["SSP1"], ["SSP1"], ["SSP1"], ["SSP2"], ["SSP2"], ["SSP2"], ["SSP2"], ["SSP2"], ["SSP2"], ["SSP2"], ["SSP2"], ["SSP2"], ["SSP3"], ["SSP3"], ["SSP3"], ["SSP3"], ["SSP3"], ["SSP3"], ["SSP3"], ["SSP3"], ["SSP3"], ["SSP4"], ["SSP4"], ["SSP4"], ["SSP4"], ["SSP4"], ["SSP4"], ["SSP4"], ["SSP4"], ["SSP4"], ["SSP5"], ["SSP5"], ["SSP5"], ["SSP5"], ["SSP5"], ["SSP5"], ["SSP5"], ["SSP5"], ["SSP5"]], "hovertemplate": "<b>%{hovertext}</b><br><br>damage=DICE<br>cost_level=5th perc.<br>abatement_costs NPV relative=%{x}<br>avoided_damages NPV relative=%{y}<br>SSP=%{customdata[0]}<extra></extra>", "hovertext": ["0.42", "0.42", "0.42", "0.62", "0.62", "0.62", "0.82", "0.82", "0.82", "0.42", "0.42", "0.42", "0.62", "0.62", "0.62", "0.82", "0.82", "0.82", "0.42", "0.42", "0.42", "0.62", "0.62", "0.62", "0.82", "0.82", "0.82", "0.42", "0.42", "0.42", "0.62", "0.62", "0.62", "0.82", "0.82", "0.82", "0.42", "0.42", "0.42", "0.62", "0.62", "0.62", "0.82", "0.82", "0.82"], "legendgroup": "DICE, 5th perc.", "marker": {"color": "#636efa", "symbol": "circle-open"}, "mode": "markers", "name": "DICE, 5th perc.", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.004080875595614455, 0.0033998631078369194, 0.0044794774621427945, 0.0066551535283527665, 0.003237958192305813, 0.00426521550336792, 0.00899480518501492, 0.004771788832404505, 0.004020095362391987, 0.009610690860616444, 0.009738433489344616, 0.010031796863179778, 0.014140131602783938, 0.009323922905616708, 0.009747181752563705, 0.01716337941400761, 0.010901600461010895, 0.009464368513040472, 0.014037795811045395, 0.014147479746318097, 0.012627654173658014, 0.01774633587508766, 0.015022405484880373, 0.012530919848109293, 0.02274863575103374, 0.01969306407294611, 0.012477436873102384, 0.006816498741647472, 0.007065743516358036, 0.00743994946139531, 0.01059139327264254, 0.0075556675645702676, 0.007186404967276467, 0.014002058901994357, 0.010464668272296022, 0.006948976436423549, 0.010785491118775624, 0.011278427435337298, 0.011045139628950847, 0.013303030145250177, 0.010812815236282181, 0.010819836889965217, 0.014563187242315761, 0.01155797417076556, 0.010596924668694866], "xaxis": "x", "y": [0.007925703406887408, 0.00711096234523993, 0.00551521475525608, 0.013109571730593893, 0.010549393793802243, 0.007685568121982821, 0.019640705112150606, 0.01625100764436041, 0.010499281501323192, 0.012025400290524775, 0.011191352675589282, 0.007969932555159905, 0.02114446851064176, 0.018307116084518803, 0.012327957014565275, 0.03241758602147479, 0.028434352285868363, 0.01799264022332271, 0.011772573046095821, 0.011641963800618447, 0.00820580537489621, 0.02011840882178632, 0.019212917683685233, 0.012718374045333696, 0.031330396430034234, 0.03023464520561854, 0.018566263574875633, 0.009059546946789867, 0.008802209678588092, 0.006480868471564521, 0.015433948526819258, 0.01389157739394661, 0.009505745256489983, 0.02356036109581719, 0.02160669680543999, 0.013437888550827127, 0.022490890910623174, 0.02082514138532896, 0.01520555384512973, 0.04130909383226068, 0.037224089634294806, 0.02630924030189638, 0.06536550715027409, 0.06007081344464654, 0.0408742317629369], "yaxis": "y"}, {"customdata": [["SSP1"], ["SSP1"], ["SSP1"], ["SSP1"], ["SSP1"], ["SSP1"], ["SSP1"], ["SSP1"], ["SSP1"], ["SSP2"], ["SSP2"], ["SSP2"], ["SSP2"], ["SSP2"], ["SSP2"], ["SSP2"], ["SSP2"], ["SSP2"], ["SSP3"], ["SSP3"], ["SSP3"], ["SSP3"], ["SSP3"], ["SSP3"], ["SSP3"], ["SSP3"], ["SSP3"], ["SSP4"], ["SSP4"], ["SSP4"], ["SSP4"], ["SSP4"], ["SSP4"], ["SSP4"], ["SSP4"], ["SSP4"], ["SSP5"], ["SSP5"], ["SSP5"], ["SSP5"], ["SSP5"], ["SSP5"], ["SSP5"], ["SSP5"], ["SSP5"]], "hovertemplate": "<b>%{hovertext}</b><br><br>damage=DICE<br>cost_level=Median<br>abatement_costs NPV relative=%{x}<br>avoided_damages NPV relative=%{y}<br>SSP=%{customdata[0]}<extra></extra>", "hovertext": ["0.42", "0.42", "0.42", "0.62", "0.62", "0.62", "0.82", "0.82", "0.8 ...

# %%
fig.write_image(f'../Paper/img/{outputfolder}/costs_vs_benefits_CE.png', scale=2)

# %%
NPV_values_combined = pd.concat((NPV_values_CE, NPV_values_CBA))
NPV_values_combined['name'] = NPV_values_combined[param_columns].agg('_'.join, axis=1)
NPV_values_combined['damage'] = pd.Categorical(NPV_values_combined['damage'], ['DICE', 'Howard Total', 'Burke (LR)'])

# %%
fig = px.line(
    NPV_values_combined, x='abatement_costs NPV relative', y='avoided_damages NPV relative',
    line_group='name', color='damage', facet_col='cost_level', facet_col_wrap=1
)

fig.update_traces(opacity=0.8, line_width=1)
fig.update_annotations(None,font_size=14)
fig.for_each_annotation(lambda a: a.update(text="Cost level: " + a.text.split("=")[-1]))

_fig2 = px.scatter(
    NPV_values_combined[NPV_values_combined['type'] == 'CBA'].sort_values(param_columns),
    x='abatement_costs NPV relative', y='avoided_damages NPV relative',
    color='damage', facet_col='cost_level', facet_col_wrap=1, symbol='cost_level', symbol_sequence=symbols
)
for trace in _fig2.data:
    fig.add_trace(trace)

fig.update_traces(showlegend=False)

for color, damage in zip(px.colors.qualitative.Plotly[:3][::-1], NPV_values_combined['damage'].unique()[::-1]):
    fig.add_trace(go.Scatter(
        x=[None],y=[None],mode='markers+lines',marker_color=color, name='Damage: {}'.format(damage), legendgroup='damage'
    ))

for symbol, cost_level in zip(symbols, NPV_values['cost_level'].unique()):
    fig.add_trace(go.Scatter(
        x=[None],y=[None],mode='markers',marker_color='#000', marker_symbol=symbol,
        name='Cost level: {}'.format(cost_level), legendgroup='cost_level'
    ))

for i in range(3):
    x_values = np.linspace(0,0.3,100)
    fig.add_trace(go.Scatter(x=x_values, y=x_values, line_color='#333', line_width=1, name='x=y line', showlegend=i==0), i+1, 1)
    
fig.update_layout(
    xaxis1={
        'range': [-0.01, 0.1627], 'title': '<b>Costs</b><br>(NPV Abatement costs / GDP)', 'tickformat': ',.0%'
    }, yaxis_range=[-0.02,0.52],
    height=1000, margin={'t': 20}, width=900,
    legend_tracegroupgap=15, legend_y=0.5, legend_font_size=13, legend_title=None
)
fig.update_yaxes(title='<b>Benefits</b><br>(NPV Avoided damages / GDP)', tickformat=',.0%')
fig.show()
# Out:
# <div>
#
#
#             <div id="e11021c4-b014-4c52-94d0-5ab24dc17dde" class="plotly-graph-div" style="height:1000px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e11021c4-b014-4c52-94d0-5ab24dc17dde")) {
#                     Plotly.newPlot(
#                         'e11021c4-b014-4c52-94d0-5ab24dc17dde',
#                         [{"hovertemplate": "damage=DICE<br>cost_level=5th perc.<br>name=SSP1_DICE_0.42_5th perc._0.0_0.5<br>abatement_costs NPV relative=%{x}<br>avoided_damages NPV relative=%{y}<extra></extra>", "legendgroup": "DICE", "line": {"color": "#636efa", "dash": "solid", "width": 1}, "mode": "lines", "name": "DICE", "opacity": 0.8, "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.004080875595614455, 0.0038655414656775817], "xaxis": "x3", "y": [0.007925703406887408, 0.007928366343234905], "yaxis": "y3"}, {"hovertemplate": "damage=DICE<br>cost_level=5th perc.<br>name=SSP1_DICE_0.42_5th perc._0.0_1.5<br>abatement_costs NPV relative=%{x}<br>avoided_damages NPV relative=%{y}<extra></extra>", "legendgroup": "DICE", "line": {"color": "#636efa", "dash": "solid", "width": 1}, "mode": "lines", "name": "DICE", "opacity": 0.8, "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.0033998631078369194, 0.0015497463164860594], "xaxis": "x3", "y": [0.00711096234523993, 0.006368903760114839], "yaxis": "y3"}, {"hovertemplate": "damage=DICE<br>cost_level=5th perc.<br>name=SSP1_DICE_0.42_5th perc._0.02_2.5<br>abatement_costs NPV relative=%{x}<br>avoided_damages NPV relative=%{y}<extra></extra>", "legendgroup": "DICE", "line": {"color": "#636efa", "dash": "solid", "width": 1}, "mode": "lines", "name": "DICE", "opacity": 0.8, "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.0044794774621427945, 0.00020603770784315316], "xaxis": "x3", "y": [0.00551521475525608, 0.004172038964617379], "yaxis": "y3"}, {"hovertemplate": "damage=DICE<br>cost_level=5th perc.<br>name=SSP1_DICE_0.62_5th perc._0.0_0.5<br>abatement_costs NPV relative=%{x}<br>avoided_damages NPV relative=%{y}<extra></extra>", "legendgroup": "DICE", "line": {"color": "#636efa", "dash": "solid", "width": 1}, "mode": "lines", "name": "DICE", "opacity": 0.8, "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.0066551535283527665, 0.006679436976978813], "xaxis": "x3", "y": [0.013109571730593893, 0.013152010957020678], "yaxis": "y3"}, {"hovertemplate": "damage=DICE<br>cost_level=5th perc.<br>name=SSP1_DICE_0.62_5th perc._0.0_1.5<br>abatement_costs NPV relative=%{x}<br>avoided_damages NPV relative=%{y}<extra></extra>", "legendgroup": "DICE", "line": {"color": "#636efa", "dash": "solid", "width": 1}, "mode": "lines", "name": "DICE", "opacity": 0.8, "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.003237958192305813, 0.003083519880793238], "xaxis": "x3", "y": [0.010549393793802243, 0.010556985370581964], "yaxis": "y3"}, {"hovertemplate": "damage=DICE<br>cost_level=5th perc.<br>name=SSP1_DICE_0.62_5th perc._0.02_2.5<br>abatement_costs NPV relative=%{x}<br>avoided_damages NPV relative=%{y}<extra></extra>", "legendgroup": "DICE", "line": {"color": "#636efa", "dash": "solid", "width": 1}, "mode": "lines", "name": "DICE", "opacity": 0.8, "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.00426521550336792, 0.0004792779589988794], "xaxis": "x3", "y": [0.007685568121982821, 0.005954759759696006], "yaxis": "y3"}, {"hovertemplate": "damage=DICE<br>cost_level=5th perc.<br>name=SSP1_DICE_0.82_5th perc._0.0_0.5<br>abatement_costs NPV relative=%{x}<br>avoided_damages NPV relative=%{y}<extra></extra>", "legendgroup": "DICE", "line": {"color": "#636efa", "dash": "solid", "width": 1}, "mode": "lines", "name": "DICE", "opacity": 0.8, "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.00899480518501492, 0.009087095401559402], "xaxis": "x3", "y": [0.019640705112150606, 0.019679223295369367], "yaxis": "y3"}, {"hovertemplate": "damage=DICE<br>cost_level=5th perc.<br>name=SSP1_DICE_0.82_5th perc._0.0_1.5<br>abatement_costs NPV relative=%{x}<br>avoided_damages NPV relative=%{y}<extra></extra>", "legendgroup": "DICE", "line": {"color": "#636efa", "dash": "solid", "width": 1}, "mode": "lines", "name": "DICE", "opacity": 0.8, "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.004771 ...

# %%
fig.write_image(f'../Paper/img/{outputfolder}/costs_vs_benefits_CBA.png', scale=2)

# %% [markdown]
# ## All carbon price paths

# %%
def make_price_and_emission_paths(selection, SSPs=['SSP1', 'SSP3', 'SSP5']):

    fig = make_subplots(
        2,3,
        subplot_titles=('Cost level: 5th perc.<br><br>Price', 'Cost level: median<br><br>  ', 'Cost level: 95th perc.<br><br>  ', 'Emissions'),
        vertical_spacing=0.15
    )

    for j, var in enumerate(['p', 'E']):
        for i, cost_level in enumerate(['5th perc.', 'Median', '95th perc.']):
            for SSP, color in zip(SSPs, colors_PBL):

                # For legend
                if i == 0 and j == 0:
                    fig.append_trace(go.Scatter(
                        x=[None], y=[None], mode='lines', line={'color': color},
                        name=SSP, showlegend=True, legendgroup='SSP'
                    ), 1, 1)

                alpha_var = 'r'
                for option, alpha in zip(r_values.keys(), [0.33, 0.66, 1]):

                    # For legend
                    if SSP == SSPs[0] and i == 0 and j == 0:
                        fig.append_trace(go.Scatter(
                            x=[None], y=[None], mode='lines', line={'color': blend('#000000', alpha)},
                            name='{}={}'.format(alpha_var, option), showlegend=True, legendgroup='r'
                        ), 1, 1)

                    selection_new = selection.loc[
                        (selection['cost_level'] == cost_level) &
                        (selection['SSP'] == SSP) &
                        (selection[alpha_var] == option) &
                        ((selection['elasmu'] == default_elasmu) | (default_elasmu == 'all')) &
                        (selection['beta'] == '2.0') &
                        #(df_CE['TCRE'].isin(['0.00038', '0.00062'])) &
                        ~((selection['damage'] == 'No damages') & selection['TCRE'].isin(['0.86', '0.38']))
                    ]
                    figtmp = px.line(selection_new, x='year', y=var, line_group='name')
                    figtmp.update_traces(line_color=blend(color, alpha))
                    for trace in figtmp.data:
                        fig.append_trace(trace, j+1, i+1)

    fig.update_layout(
        xaxis1={'range': [2020,2100]}, xaxis2={'range': [2020,2100]}, xaxis3={'range': [2020,2100]},
        xaxis4={'range': [2020,2100]}, xaxis5={'range': [2020,2100]}, xaxis6={'range': [2020,2100]},
        yaxis1={'range': [0, 598.3], 'title': 'Carbon price (US$)'},
        yaxis2={'range': [0, 1495]},
        yaxis3={'range': [0, 3843]},
        yaxis4={'range': [-27.01, 58.63], 'title': 'Emissions (GtCO2/yr)'},
        yaxis5={'range': [-27.01, 58.63]},
        yaxis6={'range': [-27.01, 58.63]},
        width=950,
        margin={'l': 0, 't': 75, 'b': 30},
        height=700,
        legend={'y': 0.5, 'font_size': 14}
    )
    
    return fig
    
fig_CE = make_price_and_emission_paths(df_CE[df_CE['damage'].isin(['No damages', 'DICE', 'Howard Total', 'Burke (LR)'])])
fig_CBA = make_price_and_emission_paths(df[df['damage'].isin(['DICE', 'Howard Total', 'Burke (LR)'])])
# fig_CE.show()
fig_CE.write_image(f'../Paper/img/{outputfolder}/CE_price_and_emission_paths.png', scale=2)
fig_CBA.write_image(f'../Paper/img/{outputfolder}/CBA_price_and_emission_paths.png', scale=2)
